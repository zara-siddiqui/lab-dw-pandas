# %%
import pandas as pd
file = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
data = pd.read_csv(file)
display(data.head())
display(data.tail())
data.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
display(data.tail())
# Out:
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 4003                   NaN                       NaN         NaN
# 4004                   NaN                       NaN         NaN
# 4005                   NaN                       NaN         NaN
# 4006                   NaN                       NaN         NaN
# 4007                   NaN                       NaN         NaN
#
#      Vehicle Class  Total Claim Amount
# 4003           NaN                 NaN
# 4004           NaN                 NaN
# 4005           NaN                 NaN
# ...

# %%
data.shape
# Out:
# (4008, 11)

# %%
data.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
data['Number of Open Complaints'] =  pd.to_numeric(data['Number of Open Complaints'], errors='coerce')
data['Customer Lifetime Value'] =  pd.to_numeric(data['Customer Lifetime Value'], errors='coerce')
data.head()
# Out:
#   Customer          ST GENDER             Education  Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor                      NaN
# 2  AI49188      Nevada      F              Bachelor                      NaN
# 3  WW63253  California      M              Bachelor                      NaN
# 4  GA49547  Washington      M  High School or Below                      NaN
#
#     Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                        NaN   Personal Auto
# 1      0.0                  94.0                        NaN   Personal Auto
# 2  48767.0                 108.0                        NaN   Personal Auto
# 3      0.0                 106.0                        NaN  Corporate Auto
# 4  36357.0                  68.0                        NaN   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
for column in data.columns:
    data_column = data[column].unique() 
    print(data_column)
# Out:
# ['RB50392' 'QZ44356' 'AI49188' ... 'CW49887' 'MY31220' nan]
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]
# [nan 'F' 'M' 'Femal' 'Male' 'female']
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor'
#  nan]
# [nan]
# [    0. 48767. 36357. 62902. 55350. 14072. 28812. 77026. 99845. 83689.
#  24599. 25049. 28855. 51148. 66140. 57749. 61040. 17870. 97541. 29723.
#  86584. 75690. 23158. 65999. 37260. 68987. 42305. 65706. 53243. 50071.
#  60021. 43244. 46896. 10105. 23218. 24804. 33190. 36014. 67163. 16701.
#  46623. 64749. 16969. 11621. 17622. 11489. 66525. 33663. 22547. 61486.
#  29879. 93011. 65186. 26840. 75644. 38984. 71811. 20961. 41275. 61321.
#  51066. 34378. 43072. 25222. 77552. 23091. 48269. 32720. 20396. 21513.
#  80744. 52822. 69738. 17780. 18107. 57740. 32627. 65795. 60475. 41837.
#  32303. 40531. 79898. 56398. 71600. 27804. 45506. 99428. 20993. 37839.
# ...

# %%
categorical_columns = data.select_dtypes(include= ['object'])
categorical_columns
# Out:
#      Customer          ST GENDER             Education     Policy Type  \
# 0     RB50392  Washington    NaN                Master   Personal Auto
# 1     QZ44356     Arizona      F              Bachelor   Personal Auto
# 2     AI49188      Nevada      F              Bachelor   Personal Auto
# 3     WW63253  California      M              Bachelor  Corporate Auto
# 4     GA49547  Washington      M  High School or Below   Personal Auto
# ...       ...         ...    ...                   ...             ...
# 4003      NaN         NaN    NaN                   NaN             NaN
# 4004      NaN         NaN    NaN                   NaN             NaN
# 4005      NaN         NaN    NaN                   NaN             NaN
# 4006      NaN         NaN    NaN                   NaN             NaN
# 4007      NaN         NaN    NaN                   NaN             NaN
#
#       Vehicle Class
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# ...

# %%
data.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints    float64
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
data._get_numeric_data()
# Out:
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                         NaN      0.0                  94.0
# 2                         NaN  48767.0                 108.0
# 3                         NaN      0.0                 106.0
# 4                         NaN  36357.0                  68.0
# ...                       ...      ...                   ...
# 4003                      NaN      NaN                   NaN
# 4004                      NaN      NaN                   NaN
# 4005                      NaN      NaN                   NaN
# 4006                      NaN      NaN                   NaN
# 4007                      NaN      NaN                   NaN
#
#       Number of Open Complaints  Total Claim Amount
# 0                           NaN            2.704934
# 1                           NaN         1131.464935
# 2                           NaN          566.472247
# ...

# %%
numerical_summary = data.describe()
display(numerical_summary)
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count                      0.0   1071.000000           1071.000000
# mean                       NaN  39295.701214            193.234360
# std                        NaN  30469.427060           1601.190369
# min                        NaN      0.000000             61.000000
# 25%                        NaN  14072.000000             68.000000
# 50%                        NaN  36234.000000             83.000000
# 75%                        NaN  64631.000000            109.500000
# max                        NaN  99960.000000          35354.000000
#
#        Number of Open Complaints  Total Claim Amount
# count                        0.0         1071.000000
# mean                         NaN          404.986909
# std                          NaN          293.027260
# min                          NaN            0.382107
# 25%                          NaN          202.157702
# ...

# %%
categorical_summary = data.select_dtypes(include=['object']).apply(pd.value_counts)
display(catergorical_summary)
# Out:
#          Customer  ST  GENDER  Education  Policy Type  Vehicle Class
# AA71604       1.0 NaN     NaN        NaN          NaN            NaN
# AB13432       1.0 NaN     NaN        NaN          NaN            NaN
# AB60627       1.0 NaN     NaN        NaN          NaN            NaN
# AB72731       1.0 NaN     NaN        NaN          NaN            NaN
# AB96670       1.0 NaN     NaN        NaN          NaN            NaN
# ...           ...  ..     ...        ...          ...            ...
# ZX64745       1.0 NaN     NaN        NaN          NaN            NaN
# ZX86243       1.0 NaN     NaN        NaN          NaN            NaN
# ZZ91716       1.0 NaN     NaN        NaN          NaN            NaN
# ZZ97035       1.0 NaN     NaN        NaN          NaN            NaN
# female        NaN NaN    28.0        NaN          NaN            NaN
#
# [1099 rows x 6 columns]

# %%
# Challenge 2

# %%
customer_location = data["ST"].value_counts()
less_common = customer_location.nsmallest(5)
display(less_common)
# Out:
# AZ             25
# WA             30
# Washington     81
# Nevada         98
# Cali          120
# Name: ST, dtype: int64

# %%
total_policies = data["Policy Type"].value_counts()
display(total_policies)
# Out:
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: Policy Type, dtype: int64

# %%
highest_policy = total_policies.idxmax()
display(highest_policy)
# Out:
# 'Personal Auto'

# %%
personal_auto = data.loc[data['Policy Type'] == 'Personal Auto']
display(personal_auto)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1065  XD85577        Cali      M              Bachelor
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                         NaN      0.0                  94.0
# 2                         NaN  48767.0                 108.0
# ...

# %%
corporate_auto = data.loc[data['Policy Type'] == 'Corporate Auto']
display(corporate_auto)
# Out:
#      Customer          ST GENDER             Education  \
# 3     WW63253  California      M              Bachelor
# 6     XZ87318      Oregon      F               College
# 7     CF85061     Arizona      M                Master
# 8     DY87989      Oregon      M              Bachelor
# 12    DP39365  California    NaN                Master
# ...       ...         ...    ...                   ...
# 1045  WZ31900      Oregon      F              Bachelor
# 1050  BJ53923     Arizona      M  High School or Below
# 1052  FB23788      Oregon      M  High School or Below
# 1056  PI47776      Oregon      F              Bachelor
# 1059  YG44474      Oregon      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 3                         NaN      0.0                 106.0
# 6                         NaN  55350.0                  67.0
# 7                         NaN      0.0                 101.0
# ...

# %%
avg_income1 = personal_auto['Income'].mean()
display(avg_income1)
# Out:
# 38180.69871794872

# %%
avg_income2 = corporate_auto['Income'].mean()
display(avg_income2)
# Out:
# 41390.31196581197
